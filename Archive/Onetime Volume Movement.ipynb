# %%
dbutils.fs.cp("/Volumes/opsanalytics_adb_workspace01/default/lab/raw_data/scc_data", 
              "/Volumes/opsanalytics_adb_workspace01/lab/raw_data/scc_data/", recurse=True)

# %%
dbutils.fs.cp("/Volumes/opsanalytics_adb_workspace01/default/lab/raw_data/power_path", 
              "/Volumes/opsanalytics_adb_workspace01/lab/raw_data/power_path/", recurse=True)
dbutils.fs.cp("/Volumes/opsanalytics_adb_workspace01/default/lab/raw_data/backlog_data", 
              "/Volumes/opsanalytics_adb_workspace01/lab/raw_data/backlog_data/", recurse=True)

# %%
dbutils.fs.rm("/Volumes/opsanalytics_adb_workspace01/default/lab/raw_data/power_path", recurse=True)
dbutils.fs.rm("/Volumes/opsanalytics_adb_workspace01/default/lab/raw_data/backlog_data", recurse=True) 
dbutils.fs.rm("/Volumes/opsanalytics_adb_workspace01/default/lab/raw_data/scc_data", recurse=True)

# %%
dbutils.fs.rm("/Volumes/opsanalytics_adb_workspace01/default/lab", recurse=True)
